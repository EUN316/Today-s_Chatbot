# %% [markdown]
# # SKT-koBERT
#
# https://github.com/SKTBrain/KoBERT

# %% [markdown]
# ## Install & Library

# %%
import torch
from torch import nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import gluonnlp as nlp
import pandas as pd
import numpy as np
from tqdm import tqdm, tqdm_notebook
import os

from KoBERT.kobert.utils import get_tokenizer
from KoBERT.kobert.pytorch_kobert import get_pytorch_kobert_model

from transformers import AdamW
from transformers.optimization import get_cosine_schedule_with_warmup

np.set_printoptions(formatter={'float_kind': lambda x: "{0:0.5f}".format(x)})

# CPU or GPU
device = 'cuda:1' if torch.cuda.is_available() else 'cpu'
device
# Out:
# 'cuda:1'

# %%
from scipy.special import softmax
pd.set_option('display.float_format', '{:.5f}'.format)
# pd.set_option('display.max_rows', None)
# pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', -1)
# Out:
# /home/hyejeongeun/.conda/envs/hyejeongeun/lib/python3.7/site-packages/ipykernel_launcher.py:5: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   """

# %% [markdown]
# ## Path

# %%
model_path = '/home/hyejeongeun/Todays_Chatbot/Model/Model/'
review_path = '/home/hyejeongeun/Todays_Chatbot/Data/Review/Review_embedding/'

# %% [markdown]
# ## Model & Tokenizer

# %%
bertmodel, vocab = get_pytorch_kobert_model()
# Out:
# [██████████████████████████████████████████████████]
# [██████████████████████████████████████████████████]

# %%
# 내장된 tokenizer와 sentencepiece 함수를 쓰는 듯
tokenizer = get_tokenizer()
tok = nlp.data.BERTSPTokenizer(tokenizer, vocab, lower=False)
# Out:
# using cached model

# %%
class BERTDataset(Dataset):
    def __init__(self, dataset, sent_idx, bert_tokenizer, max_len,
                 pad, pair):
        transform = nlp.data.BERTSentenceTransform(
            bert_tokenizer, max_seq_length=max_len, pad=pad, pair=pair)

        self.sentences = [transform([i[sent_idx]]) for i in dataset]
        #self.labels = [np.int32(i[label_idx]) for i in dataset]

    def __getitem__(self, i):
        return (self.sentences[i]) #+ (self.labels[i], ))

    def __len__(self):
        return (len(self.sentences))

# %%
## Setting parameters
max_len = 210 #210 #수정
batch_size = 16 # 64 #수정
warmup_ratio = 0.1
num_epochs = 5
max_grad_norm = 1
log_interval = 200
learning_rate =  5e-5

# %%
class BERTClassifier(nn.Module):
    def __init__(self,
                 bert,
                 hidden_size = 768,
                 num_classes=5, #2 #수정
                 dr_rate=None,
                 params=None):
        super(BERTClassifier, self).__init__()
        self.bert = bert
        self.dr_rate = dr_rate
                 
        self.classifier = nn.Linear(hidden_size , num_classes)
        if dr_rate:
            self.dropout = nn.Dropout(p=dr_rate)
    
    def gen_attention_mask(self, token_ids, valid_length):
        attention_mask = torch.zeros_like(token_ids)
        for i, v in enumerate(valid_length):
            attention_mask[i][:v] = 1
        return attention_mask.float()

    def forward(self, token_ids, valid_length, segment_ids):
        attention_mask = self.gen_attention_mask(token_ids, valid_length)
        
        _, pooler = self.bert(input_ids = token_ids, token_type_ids = segment_ids.long(), attention_mask = attention_mask.float().to(token_ids.device))
        
        classifier = self.classifier(pooler)
        
        if self.dr_rate:
            out = self.dropout(classifier)
  
        return out

# %%
model = BERTClassifier(bertmodel, dr_rate=0.5).to(device)

# %%
model.load_state_dict(torch.load(model_path+'epoch_5_qna_sep_model_4.pt'))
# Out:
# <All keys matched successfully>

# %%
model.eval()
# Out:
# BERTClassifier(
#   (bert): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(8002, 768, padding_idx=1)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (1): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (2): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (3): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (4): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (5): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (6): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (7): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (8): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (9): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (10): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (11): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (classifier): Linear(in_features=768, out_features=5, bias=True)
#   (dropout): Dropout(p=0.5, inplace=False)
# )

# %% [markdown]
# ## score & classification 출력하게 수정

# %%
def review_BERTClassifier(_dataloader):
    for batch_id, (token_ids, valid_length, segment_ids) in enumerate(_dataloader):

        token_ids = token_ids.long().to(device)
        segment_ids = segment_ids.long().to(device)
        valid_length= valid_length  

        probability = model.forward(token_ids, valid_length, segment_ids)
        probability = np.array(probability.tolist())

        if batch_id == 0:
            review_probability = probability
        else:
            review_probability = np.concatenate([review_probability, probability], axis=0)

        del probability
        torch.cuda.empty_cache() # GPU 캐시 삭제
        
    # max index 추출
    review_probability = softmax(review_probability, axis=1)
    review_class = np.argmax(review_probability, axis=1)
    score = np.max(review_probability, axis=1)
    
    return review_class, score

# %% [markdown]
# ## Review Classification

# %%
df = pd.read_csv(review_path+'review_388715_embedding.csv', sep=',')

# %%
tokens = df['comment_mecab'].tolist()

data = BERTDataset(tokens, 0, tok, max_len, True, False)
_dataloader = torch.utils.data.DataLoader(data, batch_size=batch_size, num_workers=5)

# %%
# classifier
for i in tqdm_notebook(range(1)):
    review_class, score = review_BERTClassifier(_dataloader)
# Out:
# /home/hyejeongeun/.conda/envs/hyejeongeun/lib/python3.7/site-packages/ipykernel_launcher.py:2: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
# csv 파일로 내보내기
df['score'] = score.tolist()
df['review_class_new'] = review_class.tolist()

# %%
# 기존 결과랑 변한거 없는지 확인
df[df['review_class']!=df['review_class_new']]
# Out:
# Empty DataFrame
# Columns: [created_at, writer_id, praise_count, prod_id, prod_name, prod_opt, comment, image_url, comment_spellcheck, comment_mecab, review_embedding, review_class, score, review_class_new]
# Index: []

# %%
df['review_class'].value_counts()
# Out:
# 1    13773
# 0    9848
# 2    21
# 3    6
# Name: review_class, dtype: int64

# %%
df_1 = df[['comment','score','review_class']]

# %%
"""
상품-0: 다양한 연출이 가능하고 이리저리 옮겨가며 쓰기 좋아서 굉장히 만족합니당!!!! 망가짐없이 아직도 잘 쓰고 있어요! 0.99550
배송-1: 3월 11일 낮에 주문해서 24일에 왔습니다... 제품은 마음에 드는데 배송 너무 오래걸렸네요ㅠㅠ 0.97133
교환-2: 불량을 두번이나 보내줘서 짜잉났던제품...그치만 빠르게 대처해주셔서 어렵게 완성된 제품이네효 이쁘긴합니다! 0.61859
환불-3: 환불해주세요 나사 돌리자마자 쩍 소리가 나더니\n부러졌습니다 0.93713
반품-4: X
"""

# %%
df_1[df_1['review_class']==0].sort_values(by='score', ascending=False)[:20]
# Out:
#                                                                                     comment  \
# 7037   다양한 연출이 가능하고 이리저리 옮겨가며 쓰기 좋아서 굉장히 만족합니당!!!! 망가짐없이 아직도 잘 쓰고 있어요!
# 21033  연약해보이지만 단단하게 잘조이면\n튼튼한것같기도 해요!
# 548    연장이 없어도 조립이 가능하나\n손바닥이 너무 아파요 !!
# 23576  연휴에 시켜서 배송이 많이 늦었지만 역시 이뻐요!! 근데 조립하기가 조금 힘에겹네요 ㅠ
# 11979  연휴때문에 배송느릴거라 생각했는데 너무 빨리와서 놀랬어요,,, 조립도 엄청 간단하고 디자인도 깔끔하니 넘 이뻐요 짱짱
# 6554   연결부분이 끊어졌더라구요. \n그래서 반품 할까하다가 지지하는 부분이 아니라 \n그냥 씁니다.\n물건 확인 잘하시고 보내주시면 좋겠어요
# 21591  연결나사가 육각렌치...!!ㅜㅜ 손힘이 필요하긴 하지만 가성비로 보나 디자인으로 보나 좋습니다. 아주 만족스럽게 사용중이에요!
# 21423  연결부위가 부러져서 왔네요\r\n다 조립하고 알아서.... \r\n목공풀로 붙여서 붙긴했는데 또 언제 떨어질지 불안하지만...조심히 사용중입니다
# 1474   연휴전에 받아보앗지만 불량으로 다시보내주셔서 지금에야 구매확정을 해요ㅎㅎ 통화주셔서 너무 친절하게 해주시구 만족합니당! 제품은 너무 조아유👍🏻
# 7935   푹신푹신 좋아요~~  잘 사용할께요^^
# 4322   딱 제가 찾던 테이블이에요 인기가많음거엔 이유가있는거같아요 강추합니다
# 13627  딱 작은 협탁이 필요했어요 !! 좋습니다
# 20613  예뻐요! 딱 깔끔하고 뭐 올리기 좋아요
# 13856  딱 제가 원하던 겁니다. 자기 전, 옆 탁자에서 책꺼내 좀 읽다가 자는 그런거. 윗부분이 유리로 되어있는게 더욱 마음에 들어요🧡오래오래 잘 쓰겠습니다.
# 22877  딱 예상했던 정도네요. 가격대비 만족합니다.
# 13461  딱 생각했던 것처럼 생겼어용. 이뿌고 침대옆에 두기 편하고 좋아요!조립할땐 내구성이 되게 안좋을것같았는데 막상 조립하고나니까 괜찮은것같아요!!
# 4361   딱 가격값하는거 같아요\n기스가 좀 많네요\n그래도 튼튼은 합니다
# 23029  딱 가격에 맞는 것 같습니다~ 이쁘네요
# 20531  딱 침대옆에두기 좋은고 같아여 잘산듯
# 4408   딱 좋아요~ 잘 구매한 것 같아요 ㅇ
#
#         score  \
# 7037  0.99550
# 21033 0.99550
# 548   0.99550
# 23576 0.99550
# 11979 0.99550
# 6554  0.99550
# 21591 0.99550
# 21423 0.99550
# 1474  0.99550
# 7935  0.99546
# 4322  0.99527
# 13627 0.99527
# 20613 0.99527
# 13856 0.99527
# 22877 0.99527
# 13461 0.99527
# 4361  0.99527
# 23029 0.99527
# 20531 0.99527
# 4408  0.99527
#
#        review_class
# 7037   0
# 21033  0
# 548    0
# 23576  0
# 11979  0
# 6554   0
# 21591  0
# 21423  0
# 1474   0
# 7935   0
# 4322   0
# 13627  0
# 20613  0
# 13856  0
# 22877  0
# 13461  0
# 4361   0
# 23029  0
# 20531  0
# 4408   0

# %%
df_1[df_1['review_class']==1].sort_values(by='score', ascending=False)[:20]
# Out:
#                                                                                                                                                                                                      comment  \
# 2636   호우.... 조립되게 쉽고 좋네용 옛날부터 사야지 사야지 하다가 이번기회에 삿어용 얼른 집꾸며야지><
# 3779   호야화분을 올려놓을려고 샀습니다. 사이즈 딱 제가 원하던거구요 이뻐요  근데 조립이 너무너무 힘들었습니다..\n걍 일반 나사? 였으면 더 편했을거 같아요.....\n그래도 사이즈랑 디자인은 이뻐요~
# 11097  월요일에 주문하고 수요일에 받았습니다! 배송도 빠르고 제품도 깔끔하고 너무 예쁩니다! 조립은 아빠가 해주셨만 어렵지 않았어요. 잘쓰겠습니다
# 18523  5월 24일에 사전예약 상품인 줄 모르고 주문해서 \n거의 2주가까이 기다려받았어요\n기다린 보람이 있네요ㅠ\n하나 더 주문할까해요ㅠ이쁨...!!!
# 22483  2월24일에 주문했는데 3월8일에 왔어요 배송 별점 한개주는것도 아까워요
# 15451  2월 24일에 주문해서 3월 7일에 받았어요! 그래도 오늘의 특가로 엄청 저렴하게 16,000원대에 원목 사이드테이블을 구매했습니다. 기다린 보람이 있는만큼 디자인은 예쁘네요. 나사를 조립하는건 다른 원목제품 나사조립보단 힘이 많이 들어가네요. 침대 옆에 온수냉배드 사용할때 필요한 보일러통을 둘것이 필요해서 구매했는데  딱 입니다! 잘 사용하겠습니다.
# 7414   3월 11일 낮에 주문해서 24일에 왔습니다... 제품은 마음에 드는데 배송 너무 오래걸렸네요ㅠㅠ
# 7583   2월28일에 주문했는데 오늘받았네염.... 아무것도모르고 마냥 기다렸네요 출고가 늦어지면 연락이라도 한번주시지.... 육각렌치 돌리기도 넘 빡세요 ㅠ
# 12756  9월9일이전은 추석전배송이라했는데 ..^^어제왔어요
# 23540  3월2일에결재해서15일에받았네요..배송관련해서궁금해이틀에걸쳐7번정도전화했으나한번도연결되지못하고연락한통없는등서비스는완전엉망이네요 제품은그냥가격값이랑비슷하네요 또구매할생각은없습니다
# 167    출고가 늦어진다길래 취소하려고했는데 우드제품만 늦어진거더라구요. 생각보다 빨리받았구요, 너무 이쁘긴한데 뭔가 튼튼해보이진않는 ㅠㅠ 유리가 깨질거같고.. 조립하는데도 조마조마했네여ㅠㅠ 저렴한 가격만큼한것같네여 ㅠ 그래도 조심히 쓸게여
# 7291   출고날을 넘어서 기다렸는데도 배송이 좀 늦었네요ㅜㅜ 하지만 완성하고 나니까 방 분위기도 훨씬 아늑해지고 편하기까지 합니다!! 가격 또한 너무 저렴하고 좋은 원목이라 오래 쓸 수 있을 것 같아요!! 근데 여자 혼자 조립하기엔 너무 힘듭니다ㅜㅜ 나사가 꽉 조여야하는데 힘이 부족해서 손 다까졌네요 ㅋㅋㅋ 암튼 잘쓸게여 !!!
# 19853  일단 잘박았어요 근데 실물이 너무 작아서..ㅎ제가 확실히 잿어야했는데..무튼 잘쓰겠숨돠
# 19106  일단 조립할때 유리부분이 제대로 안껴져서 고생했고요...\n조금더 쉽게 들어가고 안정적이게 들어갈수있도록 했음 좋았을텐데라는 아쉬움이...디자인과 내구성은 튼튼하니 좋은듯합니다!!
# 2577   일단 배송은 좀 늦었는데 (로젠택배 별로에요...) 상품 자체는 하자 없이 왔구요. 목장갑 끼고 조립했는데도 완성하고 나서도 손가락이 좀 아프더라구요. 여자 혼자 한시간 좀 안되게 걸렸네요. 만들고 보니 예뻐요
# 414    일단 배송도 빨리오고 디자인도 이뻐서 만족합니다!\n다른 리뷰에서 봤다시피 나사를 엄청 조여야하더라구요! 그래도 금방 조립 할 수 있어요!\n근데 위에 유리를 끼워야하는데 끼우려고 막대를 조절하니까 약간 안맞더라구요 ㅠ 그래서 삐뚤어져있는 상태입니다 ㅜ\n잘 맞지 않아서 아쉽지만 사이즈도 좋고 전반적으로 만족합니다!!
# 9330   일단 조립이 너무 간편해서 좋았어요~ 분위기도 마음에들고 너무 좋아요~
# 22166  15일 이후 배송이라더니 좀 빨리왔네요 포장도 중고같았고 제품도 다 까져서왔는데 교환하기귀찮아서 그냥써요
# 10362  23일주문하고 오늘에 받았네요\n늦게배송한다는 공지를 보긴했지만 \n기다림에 좀 지쳤습니다\n물건은 두개시켰는데 가격면에선 착하고 괜찮습니다\n여자혼자조립할수있을듯해여~\n나사 드라이버 설명서까지 쉽게되어있어요
# 16077  일단 내구성은 그냥 그래용 딱 가격값 하는 것 같아요 ㅋㅋㅋ그리고 드라이버 필요 없어서 좋았어요 드라이버같은게 같이 오더라구요? 높낮이 살짝 안맞는건 안에 들어있는 스티커같은걸로 맞췄구요 그냥 싼 맛에 산 것 같아요~~~
#
#         score  \
# 2636  0.97405
# 3779  0.97405
# 11097 0.97133
# 18523 0.97133
# 22483 0.97133
# 15451 0.97133
# 7414  0.97133
# 7583  0.97133
# 12756 0.97133
# 23540 0.97133
# 167   0.97081
# 7291  0.97081
# 19853 0.96959
# 19106 0.96959
# 2577  0.96959
# 414   0.96959
# 9330  0.96959
# 22166 0.96959
# 10362 0.96959
# 16077 0.96959
#
#        review_class
# 2636   1
# 3779   1
# 11097  1
# 18523  1
# 22483  1
# 15451  1
# 7414   1
# 7583   1
# 12756  1
# 23540  1
# 167    1
# 7291   1
# 19853  1
# 19106  1
# 2577   1
# 414    1
# 9330   1
# 22166  1
# 10362  1
# 16077  1

# %%
df_1[df_1['review_class']==2].sort_values(by='score', ascending=False)[:20]
# Out:
#                                                                                                                                                                           comment  \
# 1097   불량이 있었지만 빠른 교환처리 만족합니다~
# 1430   불량 왔어요.. 나사가 헛 돌아서 힘들어 돌아가시는줄.
# 23023  불량이와서 나사가 다안들어가요... 두군데가 그렇ㄱ습니다 환불이나 교환귀찮어서 그냥 대충사용중입니다..ㅎㅎ
# 21231  불량상품이 와서 반품하고 다시 주문한건데 조립할때 구멍들을 맞추느라 애먹었네요 해놓고 나니 이쁘긴 합니다
# 20850  불도 잘들어오고 분위기 있게 만들어줘요 ^^
# 18802  불량제품이 와서 교환하는데 너무 오래걸렸어요 가격대비 디자인도 이쁘고 쓸만하네요
# 18557  불량 왔어요 못으로 조이는 한부분이 끝까지 조여지지 않고 억지로 힘으로 조이려고 하면 부서지려고 해서 그냥  저렇게 벌어진 상태로 두고 쓰는 중이에요 이미 뜯은거 겨환 환불도 귀찮고. 디자인 인정.  근데 배송 엄청 느림
# 18072  불량이와서 그부분은 빠르게처리해주셨네요 ㅎㅎ\n이뻐요 잘쓰고있습니다~^^
# 16734  불량이 왓는지 모서리 쪽이 안맞 ... 조립도 어려웠어요
# 16081  불량을 두번이나 보내줘서 짜잉났던제품...그치만 빠르게 대처해주셔서 어렵게 완성된 제품이네효 이쁘긴합니다!
# 11294  불량품이 왔다는 리뷰가 많아서 걱정 많이 했는데 작은 찍힘 정도는 있었지만 신경 안 쓰이는 정도라 괜찮았어요 배송도 엄청 빨랐구용! 확실히 혼자 조립하기엔 힘든 거 같아요 한 쪽에서 잡아주지 않으면 나사 조이기도 힘들구 자꾸 어긋나더라구요 그치만 기대했던 대로 엄청 예뻐용 ㅠㅠ 가격 대비 맘에 들어용!!
# 11264  불량없이 깨끗한 상품으로 왔어요 ㅎㅎ 크기도 적당하고 침대사이드 협탁으로 두기에 딱이네요
# 10453  불량이 있어서 조립하기 힘들었지만 완성하고 나니깐 맘에들어요
# 8985   불끄고보면 완전이뻐요ㅋㅋㅋ\n굳굳 가격 디자인 배송 쨩
# 7366   불량처리도 잘해주시고 좋습니다 ^^ 피스가 조금만 작았으면 조립하기 편하겠네요 ^^
# 7097   은은한 불빛이 너무 마음에 들어요 ㅎㅎ
# 6863   불량품이 와서 기분이 별로네요. 부러져서 조립도 못하고 이미 포장도 다 뜯어서 교환도 어렵네요. 너무합니다.
# 5427   불량신청 했는데 빠르게 처리 해주셔서 감사해요 ~
# 1583   불량없이 왔어요! 조립도 전 나름 괜찮았고 나무인데도 갈라지는 거 없이 잘 사용중입니다 !
# 23361  불량이 왔지만 빠르게 교환처리 해주셔서 잘쓰고있어요!
#
#         score  \
# 1097  0.61859
# 1430  0.61859
# 23023 0.61859
# 21231 0.61859
# 20850 0.61859
# 18802 0.61859
# 18557 0.61859
# 18072 0.61859
# 16734 0.61859
# 16081 0.61859
# 11294 0.61859
# 11264 0.61859
# 10453 0.61859
# 8985  0.61859
# 7366  0.61859
# 7097  0.61859
# 6863  0.61859
# 5427  0.61859
# 1583  0.61859
# 23361 0.61859
#
#        review_class
# 1097   2
# 1430   2
# 23023  2
# 21231  2
# 20850  2
# 18802  2
# 18557  2
# 18072  2
# 16734  2
# 16081  2
# 11294  2
# 11264  2
# 10453  2
# 8985   2
# 7366   2
# 7097   2
# 6863   2
# 5427   2
# 1583   2
# 23361  2

# %%
df_1[df_1['review_class']==3].sort_values(by='score', ascending=False)[:20]
# Out:
#                                  comment  \
# 3140   이걸 돈 받고 팔다니 신기하다 신기해
# 14094  돈아깝다는 생각 하나도 안들고 엄청 예뻐요ㅎㅎ
# 23619  환불해주세요 나사 돌리자마자 쩍 소리가 나더니\n부러졌습니다
# 6825   값싸게 고급진 느낌 낼려면 강추해요 조립도 쉬워요
# 8872   싼 값에 샀는데 잘 쓰고 있어서 만족합니다. 디자인이 이뻐요
# 5249   액자 예뻐요!!!!! 또 살거에요 비싸긴해요..
#
#         score  \
# 3140  0.95759
# 14094 0.95759
# 23619 0.93713
# 6825  0.35955
# 8872  0.35955
# 5249  0.34339
#
#        review_class
# 3140   3
# 14094  3
# 23619  3
# 6825   3
# 8872   3
# 5249   3

# %%
df_1[df_1['review_class']==4].sort_values(by='score', ascending=False)[:20]
# Out:
# Empty DataFrame
# Columns: [comment, score, review_class]
# Index: []
